# %%
import os
os.getcwd()
os.chdir('/Users/thomassullivan/projects/GitHub/bulk_scotus/1800s')

# %%
for i in range(1800, 1900):
    try:
        i=str(i)
        os.chdir('/Users/thomassullivan/projects/GitHub/bulk_scotus/1800s')
        print(os.getcwd())
        os.chdir(str(i))
        
        os.remove('year_directory2.json')
        os.remove('year_directory3.json')
        os.remove('year_directory4.json')
        #os.chdir('/Users/thomassullivan/projects/GitHub/bulk_scotus/1800s')
    except Exception as e:
        print(e)
# Out:
# /Users/thomassullivan/projects/GitHub/bulk_scotus/1800s
# [Errno 2] No such file or directory: 'year_directory2.json'
# /Users/thomassullivan/projects/GitHub/bulk_scotus/1800s
# [Errno 2] No such file or directory: 'year_directory2.json'
# /Users/thomassullivan/projects/GitHub/bulk_scotus/1800s
# /Users/thomassullivan/projects/GitHub/bulk_scotus/1800s
# /Users/thomassullivan/projects/GitHub/bulk_scotus/1800s
# /Users/thomassullivan/projects/GitHub/bulk_scotus/1800s
# [Errno 2] No such file or directory: 'year_directory2.json'
# /Users/thomassullivan/projects/GitHub/bulk_scotus/1800s
# /Users/thomassullivan/projects/GitHub/bulk_scotus/1800s
# /Users/thomassullivan/projects/GitHub/bulk_scotus/1800s
# /Users/thomassullivan/projects/GitHub/bulk_scotus/1800s
# /Users/thomassullivan/projects/GitHub/bulk_scotus/1800s
# /Users/thomassullivan/projects/GitHub/bulk_scotus/1800s
# [Errno 2] No such file or directory: '1811'
# /Users/thomassullivan/projects/GitHub/bulk_scotus/1800s
# ...
