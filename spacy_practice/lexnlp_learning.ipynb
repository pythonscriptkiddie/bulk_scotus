# %%
import json
import os

# %%
os.getcwd()
# Out:
# '/Users/thomassullivan/projects/GitHub/bulk_scotus/lexnlp_testing'

# %%
os.chdir('/Users/thomassullivan/projects/GitHub/bulk_scotus/2000s/2008')

# %%
# Out:
# ['145791.json',
#  '145953.json',
#  '145816.json',
#  '145800.json',
#  '1331223.json',
#  '145787.json',
#  '145969.json',
#  '145928.json',
#  '1291423.json',
#  '1331167.json',
#  '1292126.json',
#  '1291395.json',
#  '145949.json',
#  '145820.json',
#  '145836.json',
#  '145973.json',
#  '145837.json',
#  '145972.json',
#  '145925.json',
#  '1290383.json',
#  '145821.json',
#  '1291140.json',
#  '1290614.json',
#  '1291137.json',
#  '145929.json',
#  '1859655.json',
#  'year_directory.json',
#  '1331170.json',
#  '145786.json',
#  '1290659.json',
#  '145801.json',
#  '145952.json',
#  '1330864.json',
#  '145817.json',
#  '145790.json',
#  '145840.json',
#  '1290644.json',
#  '1445991.json',
#  '2503049.json',
#  '145826.json',
#  '1291080.json',
#  '145830.json',
#  '145975.json',
#  '145797.json',
#  '145778.json',
#  '145955.json',
#  '145810.json',
#  '145806.json',
#  '145781.json',
#  '1290388.json',
#  '1290367.json',
#  '1291425.json',
#  '1290777.json',
# ...
