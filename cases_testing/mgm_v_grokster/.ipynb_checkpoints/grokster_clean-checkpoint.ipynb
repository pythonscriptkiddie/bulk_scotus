# %% [markdown]
# United States v. Gilman
#
# By Thomas Sullivan
#
# I am covering NFIB v. Sebelius with the aid of the BlackstoneNLP Python textual analysis library.

# %%
#test using BlackstoneNLP
#import sys
import json
import io

#modules from the community
from bs4 import BeautifulSoup



#BeautifulSoup modules

# %%
#bx = spacy.load('en_blackstone_proto') #the blackstone model
#nlp=spacy.load('en_core_web_sm') #the default spacy model

# %%
#load the json file
#import sys


#modulename = ''
#if modulename not in sys.modules:
#    print('You have not imported the {} module'.format(modulename))

# %%
with open('nfib_v_sebelius.json', 'r') as in_file:
    nfib_v_sebelius = json.load(in_file)

# %%
nfi

# %%
#gilman.keys()

# %%
#gil2 = bx(gilman['html'])

# %%
#from bs4 import BeautifulSoup
soup=BeautifulSoup(nfib_v_sebelius['plain_text'], 'html.parser')

# %%
#get the text into a separate file

with open('nfib_v_sebelius.txt', mode='w') as file_object:
    print(soup.getText(), file=file_object)

# %%
#make sure we have cleaned the data correctly:

with open('nfib_v_sebelius.txt', 'r') as file:
    data = file.read()

#dir(soup)

#a = soup.find('a', attrs={"name" : "startoftext"})
#text = a.parent.parent.get_text()

#start = re.escape("***START OF THE PROJECT GUTENBERG EBOOK JANE EYRE***")
#end = re.escape("***END OF THE PROJECT GUTENBERG EBOOK")
#text = re.search('{}(.*){}'.format(start, end), text, re.S).group(1)

#with open('Jane_Eyre.txt', 'w') as f_jane_text:
#    f_jane_text.write(text)

# %%
#print(data)

# %%
#print(data)
# Out:
# (Slip Opinion)              OCTOBER TERM, 2011                                       1
#
#                                        Syllabus
#
#          NOTE: Where it is feasible, a syllabus (headnote) will be released, as is
#        being done in connection with this case, at the time the opinion is issued.
#        The syllabus constitutes no part of the opinion of the Court but has been
#        prepared by the Reporter of Decisions for the convenience of the reader.
#        See United States v. Detroit Timber & Lumber Co., 200 U. S. 321, 337.
#
#
# SUPREME COURT OF THE UNITED STATES
#
#                                        Syllabus
#
#       NATIONAL FEDERATION OF INDEPENDENT
#
#      BUSINESS ET AL. v. SEBELIUS, SECRETARY OF
#
#         HEALTH AND HUMAN SERVICES, ET AL.
#
#
# CERTIORARI TO THE UNITED STATES COURT OF APPEALS FOR
#                 THE ELEVENTH CIRCUIT
#
# No. 11–393.      Argued March 26, 27, 28, 2012—Decided June 28, 2012*
# ...

# %%
print(soup.getText)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-b3b1b9bceb1b> in <module>
# ----> 1 print(soup.getText)
#
# NameError: name 'soup' is not defined

# %%
print('hi')

# %%
sys.stdout = old_stdout

# %%
print('hi')
