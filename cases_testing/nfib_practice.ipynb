# %% [markdown]
# Learning entity recognition using legal texts
#
# We are attempting to create a procurement tool, so mastery of vocabulary models from a diverse group of sources is a plus. You just take the skills learned in tuning one model and apply them to another model.
#
# Here, I am going to update the entity recognizer on the Obamacare opinion "National Federation of Independent Business v. Sebelius" to see if we can train it to make fewer mistakes.
#
# Our goal here is to extract several things:
#
# 1) a list of cases
# 2) a list of judges
# 3) a list of government entities
# 4) a list of organizations

# %%
#test using BlackstoneNLP

#import standard library modules
import sys
import json
import re
from typing import List, Any

#modules from the community
import spacy
from dataclasses import dataclass #backported this module from 3.7
#import lxml

from spacy import displacy
from blackstone.displacy_palette import ner_displacy_options

#blackstone improved citations
from blackstone.pipeline.sentence_segmenter import SentenceSegmenter
from blackstone.rules import CITATION_PATTERNS

import en_core_web_sm


#BeautifulSoup modules

# %%
nlp = spacy.load('en_blackstone_proto') #the blackstone model
nlp2 = en_core_web_sm.load()
#load sentence segmenter
sentence_segmenter = SentenceSegmenter(nlp.vocab, CITATION_PATTERNS)
nlp.add_pipe(sentence_segmenter, before="parser")

#nlp=spacy.load('en_core_web_sm') #the default spacy model

# %%
#Task 1: make a function to load the data from a filename

def doc_from_file(filename, model):
    with open(filename, 'r') as in_file:
        data = in_file.read()
        doc = model(data)
        return doc
    
def doc_from_json(filename: str, model: Any, dict_value: str) -> dict:
    with open(filename, 'r') as in_file:
        data=json.load(in_file)
        doc = model(data[dict_value])
        return doc
        
@dataclass
class Sentence:
    def __init__(self, num, text):
        self.num=num
        self.text=text
        self.doc=nlp(text)
        self.doc2=nlp2(text)
        self.text_as_list = [i for i in self.text]
        
        
#Task #2: make sure everything with a 'v.' in the middle is tokenized together

# %%
bx = doc_from_json(filename='nfib_v_sebelius.json', model=nlp, dict_value='plain_text')

# %%
#make sentences from a document, in this case BX  
i = 1
sents = list()
for sent in bx.sents:
    cleaned_sent = re.sub('\n|\t', '', str(sent)).strip()
    if(cleaned_sent):
        sents.append(Sentence(i, text=str(sent)))
        i += 1

# %% [markdown]
# <b>In the section above we can see the law's text displayed using displaCy. We have highlighted the cases, provisions, laws, etc in the text.</b>

# %%
sents = sents[130:] #eliminated the syllabus from the document since its not existing case law

# %%
for i in sents:
    for ent in i.doc.ents:
        print(ent.text, ent.label_)
        
        
def get_legislation_from_sentences(sentences: Any):
    '''
        args:
            sentences: 
        returns:
            legislation
    '''
    pass

def get_judges_from_sentences(sentences: Any):
    '''
        args:
            sentences: 
        returns:
            judges
    '''
    pass

def get_cases_from_sentences(sentences: Any):
    '''
        args:
            sentences: 
        returns:
            cases
    '''
    pass
# Out:
# CHIEF JUSTICE ROBERTS JUDGE
# Affordable Care Act INSTRUMENT
# Anti-Injunction Act INSTRUMENT
# United States v. Constantine CASENAME
# 296 U. S. 287 CITATION
# Bailey v. Drexel
#     Furniture Co. CASENAME
# 259 U. S. 20 CITATION
# Affordable Care Act INSTRUMENT
# §5000A PROVISION
# New York v. United States, CASENAME
# 505 U. S. 144 CITATION
# §9 PROVISION
# CHIEF JUSTICE ROBERTS JUDGE
# JUSTICE
#     KAGAN JUDGE
# (2012)                     5
#
#                               Syllabus
PROVISION
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# C. J.
#                     JUDGE
# §5000A(g)(1) PROVISION
# District Court COURT
# Northern District of Florida COURT
# Those
#  JUDGE
# National Fed- JUDGE
# Article
#  JUDGE
# Constitution INSTRUMENT
# District Court COURT
# District Court COURT
# The Court of Appeals COURT
# 648 F. 3d 1235 CITATION
# §8 PROVISION
# (2012)                    9
#
#                        Opinion of ofOBERTS CITATION
# C. J.
#                           JUDGE
# District Court COURT
# 648 F. 3d CITATION
# D. C. JUDGE
# Thomas More Law Center v.
#  CASENAME
# 651 F. 3d 529 CITATION
# Seven-Sky v. Holder CASENAME
# 661 F. 3d 1 CITATION
# CADC 2011 INSTRUMENT
# Anti-Injunction Act INSTRUMENT
# Inc.
#  JUDGE
# 671 F. 3d 391 CITATION
# District Court COURT
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# C. J.
#                       JUDGE
# Affordable Care Act INSTRUMENT
# U. S. C. JUDGE
# §1396a(a)(10) PROVISION
# The Affordable Care Act INSTRUMENT
# §1396a(a)(10)(A)(i)(VIII) PROVISION
# §1396c JUDGE
# F. 3d PROVISION
# D. C. Circuit COURT
# Anti-Injunction Act INSTRUMENT
# 651 F. 3d CITATION
# 661 F. 3d CITATION
# (2012)                  11
#
#                        Opinion of ofOBERTS CITATION
# C. J.
#                           JUDGE
# Court of Appeals COURT
# §8 PROVISION
# 648 F. 3d CITATION
# Court of Appeals COURT
# Elev-
#  JUDGE
# Care Act INSTRUMENT
# Anti-Injunction Act INSTRUMENT
# Anti-Injunction Act INSTRUMENT
# §7421(a) PROVISION
# Anti-Injunction Act INSTRUMENT
# Farr III PROVISION
# Robert A. JUDGE
# Anti-Injunction Act INSTRUMENT
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# C. J.
#                     JUDGE
# Enochs v. Williams Packing & Nav CASENAME
# 370 U. S. 1 CITATION
# Internal Revenue Code INSTRUMENT
# Anti-Injunction Act INSTRUMENT
# Anti-Injunction Act INSTRUMENT
# §7421(a) PROVISION
# Care Act INSTRUMENT
# 651 F. 3d CITATION
# Russello v.
#  CASENAME
# 464 U. S. 16 CITATION
# Anti-Injunction Act INSTRUMENT
# Congress
#  JUDGE
# (2012)          13 CITATION
# C. J. JUDGE
# Bailey v. Drexel Furniture Co. CASENAME
# S. 20 PROVISION
# 511 U. S. 767 CITATION
# Anti-Injunction Act INSTRUMENT
# Affordable Care Act INSTRUMENT
# We
#  JUDGE
# Anti-Injunction Act INSTRUMENT
# Bailey v. George CASENAME
# 259 U. S. 16 CITATION
# Drexel Furniture) CASENAME
# Anti-Injunction Act INSTRUMENT
# §6671(a) JUDGE
# Internal Revenue Code INSTRUMENT
# Title 26 PROVISION
# Anti-Injunction Act INSTRUMENT
# Code INSTRUMENT
# Title 26 PROVISION
# Anti-Injunction Act INSTRUMENT
# Section 5000A(g)(1) PROVISION
# 6671(a) JUDGE
# §5000A(g)(1) PROVISION
# Anti-Injunction Act INSTRUMENT
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# C. J.
#                     JUDGE
# §5000A(g)(1) PROVISION
# Anti-Injunction Act INSTRUMENT
# §5000A(g) PROVISION
# Brief for United States CASENAME
# F. 3d PROVISION
# Internal Revenue Code INSTRUMENT
# §6201 PROVISION
# §6301 PROVISION
# Section
#  JUDGE
# §5000A(g) PROVISION
# §5000A(g)(2)(A) PROVISION
# §5000A(g)(2)(B) PROVISION
# -Injunction Act INSTRUMENT
# section
#  JUDGE
# Internal Revenue Code INSTRUMENT
# Anti-Injunction Act INSTRUMENT
# Section
#  JUDGE
# §6201(a) PROVISION
# §6201(a) PROVISION
# Code INSTRUMENT
# (2012)          15 CITATION
# C. J. JUDGE
# §§ JUDGE
# §6671(a) PROVISION
# Code INSTRUMENT
# Code INSTRUMENT
# §6201(a JUDGE
# The Affordable Care Act INSTRUMENT
# Anti-Injunction Act INSTRUMENT
# Anti-Injunction Act INSTRUMENT
# Affordable Care Act INSTRUMENT
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# C. J. JUDGE
#
CITATION
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# C. J. JUDGE
# §5000A(a PROVISION
# §5000A(b) PROVISION
# The question is ISSUE
# Crowell v. Benson CASENAME
# 285 U. S. 22 CITATION
# Hooper v. California CASENAME
# 155 U. S. 648 CITATION
# Constitution INSTRUMENT
# (2012)           33
#
#                     Opinion of ofOBERTS CITATION
# C. J. JUDGE
# Affordable Care Act INSTRUMENT
# §5000A(b) PROVISION
# Internal Revenue Code INSTRUMENT
# United States v. Kahriger CASENAME
# 345 U. S. 22 CITATION
# Penalties for Being Uninsured CASENAME
# and Affordable Care Act INSTRUMENT
# Apr. 30 PROVISION
# Anti-Injunction Act INSTRUMENT
# Anti-Injunction Act INSTRUMENT
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# C. J.
#                     JUDGE
# Anti-Injunction Act INSTRUMENT
# Anti-Injunction Act INSTRUMENT
# 259 U. S. CITATION
# New York v.
#  CASENAME
# United States v. Constantine CASENAME
# 296 U. S. 287 CITATION
# 504 U. S. 298 CITATION
# Nelson v. Sears, Roebuck & Co. CASENAME
# 312 U. S. 359 CITATION
# United States v. Sotelo CASENAME
# 436 U. S. 268 CITATION
# (2012)                     35
#
#                         Opinion of ofOBERTS CITATION
# C. J.
#                            JUDGE
# U. S. JUDGE
# n. 5 PROVISION
# United States v. Reorganized CF&I Fabricators of Utah CASENAME
# 518 U. S. 213 CITATION
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# C. J.
#                       JUDGE
# §5000A(g)(2) PROVISION
# Drexel Furni- JUDGE
# W. Brownlee, Federal Taxation CASENAME
# America 22 PROVISION
# United States §962 INSTRUMENT
# PPACA 7 PROVISION
# n. 25 PROVISION
# (2012)           37 CITATION
# C. J.
#                       JUDGE
# United States v. Sanchez CASENAME
# 340 U. S. 42 CITATION
# Sonzinsky v. United States, CASENAME
# 300 U. S. 506 CITATION
# §5000A JUDGE
# United States v. Reorganized CF&I Fabricators of Utah CASENAME
# 518 U. S. 213 CITATION
# United States v. La CASENAME
# 282 U. S. 568 CITATION
# Mar. 26 PROVISION
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# C. J.
#                       JUDGE
# §5000A PROVISION
# New York v. United States CASENAME
# 505 U. S. CITATION
# §2021c(a)(1)(A) PROVISION
# 505 U. S. CITATION
# Constitution INSTRUMENT
# We
#  JUDGE
# We
#  JUDGE
# New York v. United States CASENAME
# 505 U. S. CASENAME
# (2012)                  39
#
#                       Opinion of ofOBERTS CITATION
# C. J. JUDGE
# §5000A JUDGE
# Sup-
#  JUDGE
# §5000A PROVISION
# §5000A PROVISION
# Woods v. Cloyd W. Miller Co. CASENAME
# 333 U. S. CITATION
# 42 U. S. C. §2021e(e)(1)
#
#  CASENAME
# §2021e(e)(2) PROVISION
# 505 U. S. CASENAME
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# C. J.
#                     JUDGE
# Constitution INSTRUMENT
# §9 PROVISION
# Springer v. United States, CASENAME
# 102 U. S. 586 CITATION
# Hylton v. United States CASENAME
# (2012)          41 CITATION
# C. J.
#                       JUDGE
# Pollock v. Farmers’ Loan & Trust Co. CASENAME
# 158 U. S. 601 CITATION
# Eisner v. Macom- CASENAME
# 252 U. S. 189 CITATION
# §5000A(b) PROVISION
# Constitution INSTRUMENT
# Constitution INSTRUMENT
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# C. J.
#                     JUDGE
# Nov. 13 PROVISION
# United States v. Butler CASENAME
# 297 U. S. 1 CASENAME
# 259 U. S. 20 CITATION
# U. S. JUDGE
# Kurth
#                  Cite JUDGE
# (2012)           43 CITATION
# C. J.
#                       JUDGE
# 511 U. S. CITATION
# 336 U. S. 342 CITATION
# Oil Co. v. Mississippi ex CASENAME
# 277 U. S. 218 CITATION
# (1928) (Holmes CITATION
# NATIONAL FEDERATION OF INDEPENDENT
#                     JUDGE
# C. J. JUDGE
# choice.11
#   The Affordable Care Act’s CASENAME
# Constitution INSTRUMENT
# JUSTICE GINSBURG JUDGE
# §5000A JUDGE
# Constitution INSTRUMENT
# Section 5000A JUDGE
# Section 5000A PROVISION
# U. S. C. JUDGE
# §5000A(g)(2) PROVISION
# (2012)          45 CITATION
# C. J. JUDGE
# IV
#
#                               A
#
#   The CITATION
# State’s Medicaid JUDGE
# 505 U. S. CITATION
# §1396a(a)(10) PROVISION
# Pressure 11 PROVISION
# Affordable Care Act INSTRUMENT
# Medicaid pro- JUDGE
# §1396a(a)(10)(A)(i)(VIII) PROVISION
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# C. J. JUDGE
# Care Act INSTRUMENT
# Douglas W. JUDGE
# Table 2 PROVISION
# §8 PROVISION
# Barnes v. Gorman CASENAME
# 536 U. S. 181 CITATION
# Hospital v. Halderman CASENAME
# 451 U. S. 1 CITATION
# (2012)          47 CITATION
# C. J. JUDGE
# U. S. JUDGE
# Alden v. Maine CASENAME
# S. 706 PROVISION
# Constitution INSTRUMENT
# 521 U. S. CITATION
# Steward Machine Co. v. Davis CASENAME
# 301 U. S. 548 CITATION
# T]he Constitution INSTRUMENT
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# C. J. JUDGE
# 301 U. S. CITATION
# Federal Gov- JUDGE
# (2012)          49 CITATION
# C. J. JUDGE
# Con-
#  JUDGE
# Massachusetts v. Mellon CASENAME
# 262 U. S. 447 CITATION
# Some-
#  JUDGE
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# C. J. JUDGE
# South Dakota v. Dole CASENAME
# U. S. JUDGE
# 483 U. S. CITATION
# (2012)          51 CITATION
# C. J. JUDGE
# State
#  JUDGE
# Report 59 PROVISION
# South Dakota v. Dole CASENAME
# 791 F. 2d CITATION
# 483 U. S. CITATION
# Section 1396c JUDGE
# Medi-
#  JUDGE
# §1396c JUDGE
# Affordable Care Act INSTRUMENT
# Medicaid
#  JUDGE
# §1396d(b) PROVISION
# Federal Gov- JUDGE
# Brief for United States CASENAME
# Dole Court COURT
# NATIONAL FEDERATION OF INDEPENDENT
#                     JUDGE
# C. J. JUDGE
# 483 U. S. CITATION
# Medicaid
#  JUDGE
# JUSTICE GINSBURG JUDGE
# Care Act INSTRUMENT
# Medicaid
#  JUDGE
# JUSTICE  GINSBURG JUDGE
# (2012)          53 CITATION
# C. J.
#
#     JUDGE
# Social Security Act INSTRUMENT
# §1304 PROVISION
# 451 U. S. CITATION
# Social Security Act INSTRUMENT
# Omnibus Budget Reconciliation Act INSTRUMENT
# §4601 PROVISION
# U. S. C. JUDGE
# §1396a(a)(10) PROVISION
# Affordable Care Act INSTRUMENT
# NATIONAL FEDERATION OF INDEPENDENT
#                     JUDGE
# C. J. JUDGE
# §1396d(b) PROVISION
# §1396d(y)(1) PROVISION
# Con-
#  JUDGE
# States 9 PROVISION
# Medicaid
#  JUDGE
# JUSTICE GINSBURG JUDGE
# JUSTICE GINSBURG JUDGE
# JUSTICE GINSBURG JUDGE
# (2012)           55 CITATION
# C. J. JUDGE
# Previous Medicaid
#  JUDGE
# FERC v. Mississippi CASENAME
# 456 U. S. 742 CITATION
# Affordable Care Act INSTRUMENT
# Section 1396c JUDGE
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# C. J. JUDGE
# §1396c JUDGE
# United States Code INSTRUMENT
# §1396c JUDGE
# §1303 PROVISION
# Affordable Care Act INSTRUMENT
# Constitution INSTRUMENT
# Affordable Care Act INSTRUMENT
# (2012)           57 CITATION
# C. J. JUDGE
# United States v. Booker CASENAME
# 543 U. S. 220 CITATION
# Ayotte v. Planned CASENAME
# Parenthood of Northern New Eng CASENAME
# 546 U. S. 320 CITATION
# Medicaid
#  JUDGE
# Champlin Refining JUDGE
# Co. v. Corporation Comm’n CASENAME
# 286 U. S. 210 CITATION
# We disagree CONCLUSION
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# C. J. JUDGE
# Affordable Care Act INSTRUMENT
# Care Act INSTRUMENT
# (2012)                 59 CITATION
# C. J. JUDGE
# Care Act INSTRUMENT
# Care Act INSTRUMENT
# Constitution INSTRUMENT
# Court of Appeals COURT
# (2012)           1
#
#                     Opinion of GINSBURG CITATION
# SUPREME COURT COURT
# PETITIONERS
#  JUDGE
# 11–393                 v.
#    CONCLUSION
# PETITIONERS
#
#  JUDGE
# 11–398                  JUDGE
# PETITIONERS
#  JUDGE
# ON WRITS OF CERTIORARI JUDGE
# UNITED STATES COURT COURT
# JUSTICE SOTOMAYOR JUDGE
# JUSTICE
#  JUDGE
# I agree CONCLUSION
# CHIEF JUSTICE JUDGE
# CHIEF JUSTICE JUDGE
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# J.
#
#
#  JUDGE
# Social Secu- JUDGE
# CHIEF JUSTICE JUDGE
# United States v. Darby CASENAME
# S. 100 PROVISION
# Hammer v. Dagenhart CASENAME
# 247 U. S. 251 CITATION
# NLRB v. Jones CASENAME
# Steel Corp. JUDGE
# 301 U. S. 1 CASENAME
# CHIEF JUSTICE JUDGE
# Alton R. Co. COURT
# 295 U. S. 330 CITATION
# (2012)           3
#
#                     Opinion of GINSBURG CITATION
# Commerce Act INSTRUMENT
# §18091(2)(B) PROVISION
# National Health Interview Survey 2009 INSTRUMENT
# Table 37 PROVISION
# Table 34 PROVISION
# Medicaid Services, Historic National Health CASENAME
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# Se-
#  JUDGE
# 39 Health Service Research 627 CASENAME
# Value of Health Insurance CASENAME
# Amici Curiae JUDGE
# Apr. 5 PROVISION
# Medicare
#  JUDGE
# (2012)            5
#
#                     Opinion of GINSBURG CITATION
# Outlook 37 PROVISION
# DeNavas-Walt JUDGE
# Table 8 PROVISION
# Hidden
#  JUDGE
# Americans Pay a Premium CASENAME
# Table 79 PROVISION
# 42 U. S. C. §18091(2) CASENAME
# Health & Safety Code INSTRUMENT
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# Opinion 8.11 JUDGE
# Neglect of Patient JUDGE
# §18091(2)(F) PROVISION
# (2012)              7
#
#                      Opinion of GINSBURG CITATION
# Recommendations 43 PROVISION
# Coverage, Washington Post (May 7 CASENAME
# 05/07/gIQALNHN8T_print.html JUDGE
# Helvering v. Davis CASENAME
# 301 U. S. 619 CITATION
# Brief for Commonwealth of Massachusetts as Amicus CASENAME
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# J.
#
#
# Curiae JUDGE
# 301 U. S. CITATION
# Brief for Health Care CASENAME
# (2012)                   9
#
#                        Opinion of GINSBURG CITATION
# 42 U. S. C. §18091(2)(C CASENAME
# (2006 CITATION
# 26 U. S. C. §5000A. CASENAME
# Medicaid cover­ JUDGE
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# J.
#
#
#  JUDGE
# §300gg PROVISION
# (2012)           11
#
#                     Opinion of GINSBURG CITATION
# Amici Curiae JUDGE
# Brief for Governor of Washington Christine CASENAME
# AAPD Brief CASENAME
# L. 71 PROVISION
# Brief
#  JUDGE
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# J.
#
#
#  JUDGE
# CHIEF JUSTICE JUDGE
# CHIEF JUSTICE JUDGE
# Affordable Care Act INSTRUMENT
# 514 U. S. CITATION
# Employee Retirement Income Security Act INSTRUMENT
# Accountability Act PROVISION
# Exam­
#  JUDGE
# §1866(g) PROVISION
# U. S. C. JUDGE
# Uniform Militia Act INSTRUMENT
# Nortz v. United States, CASENAME
# 294 U. S. 317 CITATION
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# J.
#
#
#  JUDGE
# Brief 15–26 JUDGE
# (2012)                   37 CITATION
# Carter Coal Co. CASENAME
# 298 U. S. CITATION
# 247 U. S. CITATION
# Lochner v. New York CASENAME
# 198 U. S. 45 CITATION
# CHIEF JUSTICE’s Commerce JUDGE
# §8 PROVISION
# CHIEF JUSTICE JUDGE
# CHIEF
#  JUDGE
# Richland County COURT
# 538 U. S. 456 CITATION
# 538 U. S. CITATION
# CHIEF JUSTICE JUDGE
# CHIEF JUSTICE JUDGE
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# J.
#
#
#                                JUDGE
# Guaranteed eligibil­ JUDGE
# age 65 PROVISION
# 451 U. S. 1 CITATION
# 2010 Medicaid COURT
# (2012)          39 CITATION
# Medicaid
#  JUDGE
# Medicaid Act INSTRUMENT
# §1304 PROVISION
# §430.12(c)(i) PROVISION
# Medicaid Act INSTRUMENT
# CHIEF JUSTICE JUDGE
# CHIEF JUSTICE JUDGE
# Medicaid pro­ JUDGE
# CHIEF JUSTICE JUDGE
# CHIEF JUSTICE JUDGE
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# Federal Gov­ JUDGE
# CHIEF JUSTICE JUDGE
# I
#  JUDGE
# CHIEF JUSTICE JUDGE
# Brockett v.
#  CASENAME
# 472 U. S. 491 CITATION
# U. S. C. JUDGE
# §1303 PROVISION
# CHIEF JUSTICE JUDGE
# (2012)                  41 CITATION
# Medicaid pro­ JUDGE
# Medicaid Act INSTRUMENT
# Permanently and Totally Disabled INSTRUMENT
# §121(a) PROVISION
# Schweiker v. Gray Panthers CASENAME
# 453 U. S. 34 CITATION
# Medicaid pro­ JUDGE
# L. 431 PROVISION
# America 51 PROVISION
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# J.
#
#
#  JUDGE
# 42 U. S. C.
#  CASENAME
# §§1396a(a)(10)(A)(i JUDGE
# Medicare Catastrophic Cov­ JUDGE
# Act of 1988 INSTRUMENT
# §302 PROVISION
# Reconciliation Act INSTRUMENT
# §6401 PROVISION
# Budget Reconciliation Act of 1990 INSTRUMENT
# §4601 PROVISION
# Medicaid Expansions for Children COURT
# Pregnant
#  JUDGE
# Women 5 PROVISION
# Medicaid spend­ JUDGE
# Calendar
#  JUDGE
# U. S. C. JUDGE
# §1396d(y) PROVISION
# (2012)                    43 CITATION
# CBO, Spending & Enrollment
#  CASENAME
# T]he Act INSTRUMENT
# FERC v. Mississippi CASENAME
# 456 U. S. 742 CITATION
# 534 U. S. 473 CITATION
# Harris
#  JUDGE
# 448 U. S. 297 CITATION
# Brief for Petitioners
#
#  CASENAME
# Reform 16 PROVISION
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# J.
#
#
#  JUDGE
# Medicaid Act INSTRUMENT
# Caminker, State Sovereignty CASENAME
# L. Rev. JUDGE
# Schweiker v. Gray Panthers CASENAME
# 453 U. S. 34 CITATION
# (2012)                  45
#
#                        Opinion of GINSBURG CITATION
# Rose-Ackerman, Cooperative Federalism CASENAME
# Yale L. J. JUDGE
# Savings Bank v. Florida Prepaid Postsecondary Ed CASENAME
# 527 U. S. 666 CITATION
# §8 PROVISION
# 451 U. S. CITATION
# Medicaid
#  JUDGE
# CHIEF JUSTICE JUDGE
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# J.
#
#
#  JUDGE
# 448 U. S. CITATION
# Medicaid
#  JUDGE
# 547 U. S. 268 CITATION
# Frew v. Hawkins CASENAME
# S. 431 PROVISION
# Atkins v. Rivera CASENAME
# 477 U. S. 154 CITATION
# Bennett v. Kentucky Dept CASENAME
# South Dakota v. Dole CASENAME
# 483 U. S. 203 CITATION
# 648 F. 3d 1235 CITATION
# CHIEF JUSTICE JUDGE
# (2012)          47 CITATION
# Steward Machine Co. v.
#  CASENAME
# 301 U. S. 548 CITATION
# National Minimum Drinking Age Act INSTRUMENT
# §158 PROVISION
# Medicaid
#  JUDGE
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# J.
#
#
#  JUDGE
# CHIEF JUSTICE JUDGE
# Medicaid expan­ JUDGE
# CHIEF JUSTICE JUDGE
# CHIEF JUSTICE JUDGE
# CHIEF JUSTICE’s JUDGE
# CHIEF JUSTICE JUDGE
# S. Rep. JUDGE
# (2012)          49 CITATION
# §121(a) PROVISION
# Medicaid Act INSTRUMENT
# §1396b(v) PROVISION
# §2001(a)(1 PROVISION
# Medicaid Act INSTRUMENT
# U. S. C. JUDGE
# Medicaid expan­ JUDGE
# Medicaid Act INSTRUMENT
# §2001 PROVISION
# Title 42 PROVISION
# Chapter 7 PROVISION
# Medicaid Act PROVISION
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# Helvering v. Davis CASENAME
# Steward Machine CASENAME
# 301 U. S. CITATION
# CHIEF JUSTICE JUDGE
# year—133% JUDGE
# CHIEF JUSTICE JUDGE
# §§1396–1396v(b) CITATION
# §1396a(a) PROVISION
# Deficit Reduction Act INSTRUMENT
# (2012)                  51 CITATION
# CHIEF JUSTICE JUDGE
# §1396d(b) PROVISION
# §1396d(y) PROVISION
# Brief
#  JUDGE
# CHIEF JUSTICE JUDGE
# Medicaid pro­ JUDGE
# CHIEF
#  JUDGE
# §6044 PROVISION
# §1396a(k) PROVISION
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# J.
#
#
# JUSTICE JUDGE
# Hospital v. Halderman CASENAME
# 451 U. S. 1 CITATION
# Developmentally Disabled INSTRUMENT
# Rights Act INSTRUMENT
# Section 2001 PROVISION
# 42 U. S. C. §1396a(a)(10)(A) CASENAME
# CHIEF JUSTICE JUDGE
# (2012)                  53 CITATION
# Bennett v. New Jersey CASENAME
# 470 U. S. 632 CITATION
# U. S. JUDGE
# 451 U. S. CITATION
# Bennett v. Kentucky Dept CASENAME
# Commonwealth’s 1974 INSTRUMENT
# Rejecting
#  JUDGE
# CHIEF JUSTICE JUDGE
# Bennett v. Kentucky Dept CASENAME
# 470 U. S. 656 CITATION
# Elementary and Secondary Education Act INSTRUMENT
# Bennett v. New Jersey CASENAME
# 470 U. S. 632 CITATION
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# Federal Aid Highway Act INSTRUMENT
# Medicaid Act INSTRUMENT
# Railroad Passenger Corporation v. Atchison CASENAME
# 470 U. S. 451 CITATION
# 99 U. S. 700 CITATION
# Bowen v. Public Agencies Opposed CASENAME
# 477 U. S. 41 CITATION
# Social Security Act INSTRUMENT
# (2012)           55
#
#                     Opinion of GINSBURG CITATION
# Concerned that
#  JUDGE
# CHIEF JUSTICE JUDGE
# §1304 PROVISION
# §1304 PROVISION
# Delta Air JUDGE
# Inc. v. August CASENAME
# 450 U. S. 346 CITATION
# §1304 PROVISION
# §430.12(c)(1) PROVISION
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# Security Act Medical Assistance Program §7.1 INSTRUMENT
# CHIEF JUSTICE JUDGE
# Brief for National Health Law Program et al CASENAME
# Curiae 16–18 JUDGE
# §1304 PROVISION
# §1304 PROVISION
# CHIEF JUSTICE JUDGE
# Security Act PROVISION
# Social Security Act INSTRUMENT
# §103 PROVISION
# (2012)                       57 CITATION
# CHIEF JUSTICE JUDGE
# Steward Machine CASENAME
# 301 U. S. CITATION
# CHIEF JUSTICE JUDGE
# NATIONAL FEDERATION OF JUDGE
# J.
#
#
#  JUDGE
# 301 U. S. CITATION
# 483 U. S. 203 CITATION
# Inc. v. Thornton CASENAME
# 514 U. S. 779 CITATION
# (2012)                 59 CITATION
# Baker
#  JUDGE
# 369 U. S. 186 CITATION
# Baker & Berman, Getting CASENAME
# n. 307 PROVISION
# Law of Rules INSTRUMENT
# L. Rev. JUDGE
# Brief for David Satcher et CASENAME
# Curiae 19 PROVISION
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# J.
#
#
#  JUDGE
# Medicaid Act INSTRUMENT
# CHIEF
#  JUDGE
# Constitution INSTRUMENT
# I
#  JUDGE
# Court of Appeals COURT
# CHIEF JUSTICE JUDGE
# I agree CONCLUSION
# Medicaid Act INSTRUMENT
# Medicaid Act INSTRUMENT
# CHIEF JUSTICE JUDGE
# §80.10(f) PROVISION
# (2012)          61 CITATION
# §1303 PROVISION
# Ayotte v.
#  CASENAME
# Planned Parenthood of Northern New Eng CASENAME
# 546 U. S. 320 CITATION
# CHIEF JUSTICE JUDGE
# Part IV PROVISION
# CHIEF
#  JUDGE
# I agree CONCLUSION
# CHIEF JUSTICE JUDGE
# Court of Appeals COURT
# Medicaid
#  JUDGE
# (2012)             1
#
#          SCALIA CITATION
# SUPREME COURT COURT
# PETITIONERS
#  JUDGE
# 11–393                 v.
#    CONCLUSION
# PETITIONERS
#
#  JUDGE
# 11–398                  JUDGE
# PETITIONERS
#  JUDGE
# ON WRITS OF CERTIORARI JUDGE
# UNITED STATES COURT COURT
# Constitution INSTRUMENT
# Affordable Care Act (Affordable Care Act INSTRUMENT
# NATIONAL FEDERATION JUDGE
# §8 PROVISION
# 1789 Constitution INSTRUMENT
# Wickard v. Filburn CASENAME
# 317 U. S. 111 CITATION
# (2012)             3
#
#        SCALIA CITATION
# United States v. Butler CASENAME
# 297 U. S. 1 CITATION
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# §8 PROVISION
# U. S. C. JUDGE
# §5000A(a) PROVISION
# Gibbons v. Ogden CASENAME
# Chief
#  JUDGE
# Justice Marshall JUDGE
# English Lan- JUDGE
# T.
#  JUDGE
# Dyche & W. JUDGE
# (2012)
#                  5 CITATION
# U. S. JUDGE
# §8 PROVISION
# §5000A PROVISION
# Affordable Care Act INSTRUMENT
# ) 24 PROVISION
# hereinafter Petitioners’ Minimum Coverage Brief) CASENAME
# T. Cunning- JUDGE
# NATIONAL FEDERATION JUDGE
# 42 U. S. C. §18091(2)(H) CASENAME
# §300gg–3 PROVISION
# (2012)             7
#
#         SCALIA CITATION
# NLRB v. Jones & Laughlin Steel CASENAME
# 301 U. S. 1 CITATION
# NATIONAL FEDERATION JUDGE
# New York v. United States, CASENAME
# 505 U. S. 144 CITATION
# Printz v. United States, CASENAME
# 521 U. S. CITATION
# 514 U. S. 549 CITATION
# United States v. Morrison CASENAME
# 529 U. S. 598 CITATION
# (2012)             9
#
#         SCALIA CITATION
# Gonzales v. Raich CASENAME
# 545 U. S. 1 CITATION
# Raich
#  JUDGE
# 317 U. S. 111 CITATION
# Shreveport Rate Cases CASENAME
# 234 U. S. CITATION
# NATIONAL FEDERATION JUDGE
# Andrus v. Allard CASENAME
# 444 U. S. 51 CITATION
# Bill of Rights COURT
# Mar. 27 PROVISION
# 514 U. S. CITATION
# Section 5000A PROVISION
# §5000A PROVISION
# Shreveport Rate Cases CASENAME
# (2012)                11 CITATION
# §5000A JUDGE
# Minimum Coverage Brief CASENAME
# §5000A JUDGE
# JUSTICE GINSBURG JUDGE
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# Brief 34 PROVISION
# Wickard v. Filburn CASENAME
# Perez v. United States, CASENAME
# 402 U. S. 146 CITATION
# Clerk of Court COURT
# (2012)             13
#
#         SCALIA CITATION
# JUSTICE GINSBURG JUDGE
# the test LEGAL_TEST
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# Com-
#  JUDGE
# Social Security Act INSTRUMENT
# JUSTICE GINSBURG JUDGE
# (2012)                   15 CITATION
# Constitution INSTRUMENT
# Article I JUDGE
# NATIONAL FEDERATION JUDGE
# Constitution INSTRUMENT
# JUSTICE GINSBURG JUDGE
# §5000A PROVISION
# (2012)                  17
#
#          SCALIA CITATION
# §5000A PROVISION
# COVERAGE PROVISION IS INDEPENDENTLY JUDGE
# CONGRESS’S TAXING POWER JUDGE
# Brief 52 PROVISION
# MINIMUM COVERAGE JUDGE
# PENALTY BUT A JUDGE
# The issue is ISSUE
# United States v. Sotelo CASENAME
# 436 U. S. 268 CITATION
# Bankruptcy Code INSTRUMENT
# Bankruptcy Code INSTRUMENT
# NATIONAL FEDERATION JUDGE
# Crowell v. Benson CASENAME
# 285 U. S. 22 CITATION
# Commodity Futures Trading Comm’n v. Schor CASENAME
# Aptheker v. Secretary of State CASENAME
# 378 U. S. 500 CITATION
# Scales v. United CASENAME
# 367 U. S. 203 CITATION
# Grenada County COURT
# 112 U. S. 261 CITATION
# United States v. Reorganized CF&I Fabricators of Utah CASENAME
# 518 U. S. 213 CITATION
# United States v. La CASENAME
# 282 U. S. 568 CITATION
# act
#                    Cite JUDGE
# (2012)
#             19 CITATION
# Child Labor Tax Case INSTRUMENT
# 259 U. S. 20 CITATION
# U. S. C. § JUDGE
# 42 U. S. C.
#  CASENAME
# §18091(2)(A) JUDGE
# §18091(2)(C) PROVISION
# §18091(2)(D) PROVISION
# §18091(2)(H) PROVISION
# Federal regu- JUDGE
# §18091(3) PROVISION
# Supreme Court COURT
# New York v. United States, CASENAME
# 505 U. S. 144 CITATION
# NATIONAL FEDERATION JUDGE
# U. S. C. JUDGE
# §2021c(a)(1)(A PROVISION
# §2021c(a)(1)(A) PROVISION
# 505 U. S. CITATION
# §5000A(b)(1) PROVISION
# Powhatan Steamboat Co. v. Appomattox R.
#  CASENAME
# Chancel-
#  JUDGE
# Law 436 PROVISION
# (2012)
#             21 CITATION
# New York v. United States CASENAME
# §5000A(b) PROVISION
# §5000A PROVISION
# Section
#  JUDGE
# §5000A(d)(2) PROVISION
# §5000A(d)(3) PROVISION
# §5000A(d)(4) PROVISION
# Section 5000A(e) PROVISION
# mini- INSTRUMENT
# §5000A(e)(1) PROVISION
# §5000A(e)(2) PROVISION
# §5000A(e)(3) PROVISION
# §5000A(e)(4) PROVISION
# §5000A(e)(5) PROVISION
# NATIONAL FEDERATION JUDGE
# Section 5000A PROVISION
# Brief 61 PROVISION
# Mar. 26 PROVISION
# Affordable Care Act INSTRUMENT
# Social Ser- JUDGE
# §5000A PROVISION
# Internal Revenue Code INSTRUMENT
# Internal
#                    Cite COURT
# (2012)
#             23 CITATION
# Petitioners’ Minimum Coverage Brief CASENAME
# §5761(c) PROVISION
# §9707 PROVISION
# Reorganized CF&I JUDGE
# Lipke v. Lederer CASENAME
# 259 U. S. 557 CITATION
# §5000A PROVISION
# §5000A(e)(1)(D) PROVISION
# Petitioners’ Minimum Coverage Brief CASENAME
# §488e(c) PROVISION
# NATIONAL FEDERATION JUDGE
# §§7734(b)(2) CITATION
# §§1701q–1(d)(3) CITATION
# U. S. C. JUDGE
# §2716a(a PROVISION
# Staples v. United States, CASENAME
# 511 U. S. 600 CITATION
# Parsons v.
#  CASENAME
# Individual Man- JUDGE
# Stamp Act INSTRUMENT
# Constitution INSTRUMENT
# House of Repre- COURT
# §7 PROVISION
# (2012)
#             25 CITATION
# 495 U. S. 385 CITATION
# Act of 2009 INSTRUMENT
# S. 1796 PROVISION
# §5000A PROVISION
# §9 PROVISION
# §5000A JUDGE
# Brief 25 PROVISION
# Oral Arg JUDGE
# Mar. 27 PROVISION
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# Individual Man- JUDGE
# Anti-Injunction Act INSTRUMENT
# Hav-
#  JUDGE
# §6671(a) PROVISION
# Anti-Injunction Act INSTRUMENT
# Anti-Injunction Act INSTRUMENT
# Revenue Code INSTRUMENT
# §6901(a) JUDGE
# §6305(a) PROVISION
# (2012)
#                  27 CITATION
# §5000A JUDGE
# Anti-Injunction Act INSTRUMENT
# Anti-Injunction Act INSTRUMENT
# Anti-Injunction Act INSTRUMENT
# 259 U. S. 16 CITATION
# Child Labor Tax Case INSTRUMENT
# Anti-Injunction Act INSTRUMENT
# Injunction Act INSTRUMENT
# Code INSTRUMENT
# Anti-Injunction Act INSTRUMENT
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# Anti-Injunction Act INSTRUMENT
# Constitution INSTRUMENT
# (2012)             29 CITATION
# Medicaid pro- JUDGE
# Constitution INSTRUMENT
# §8 PROVISION
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# 297 U. S. CITATION
# Court, Justice Roberts COURT
# Article I JUDGE
# Constitution INSTRUMENT
# section 8 PROVISION
# Steward Machine Co. v. Davis CASENAME
# 301 U. S. CITATION
# Helvering v. Davis CASENAME
# 301 U. S. 619 CITATION
# Mone-
#                       Cite JUDGE
# (2012)                31
#
#            SCALIA CITATION
# Polity 83 PROVISION
# Pennhurst State School and Hospital v. Halderman CASENAME
# 451 U. S. 1 CITATION
# South Dakota v. Dole CASENAME
# 483 U. S. CITATION
# Fullilove v. Klutznick CASENAME
# 448 U. S. 448 CITATION
# Fiscal Year 2005 INSTRUMENT
# Office of Management and Budget, Historical Tables, Budget CASENAME
# U. S. Government COURT
# Fiscal Year 2005 INSTRUMENT
# Table 419 PROVISION
# Federal Grants- JUDGE
# NATIONAL FEDERATION JUDGE
# Article I JUDGE
# College Savings Bank v. Florida Prepaid CASENAME
# 527 U. S. 666 CITATION
# Constitution INSTRUMENT
# Article I’s JUDGE
# Davis v. Monroe County CASENAME
# S. 629 PROVISION
# 297 U. S. CITATION
# (2012)             33 CITATION
# Massachusetts v. United States, CASENAME
# 435 U. S. 444 CITATION
# Lawrence County JUDGE
# U. S. JUDGE
# Accord, College Savings Bank CASENAME
# Metropolitan Washington Airports Authority v. Citizens CASENAME
# Abatement of Aircraft Noise, Inc., CASENAME
# 501 U. S. 252 CITATION
# Barnes v. Gorman CASENAME
# 536 U. S. 181 CITATION
# 451 U. S. CITATION
# 505 U. S. CITATION
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# 505 U. S. CITATION
# (2012)
#             35 CITATION
# 505 U. S. CITATION
# South Dakota v. Dole CASENAME
# South Dakota v. Dole CASENAME
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# 483 U. S. CITATION
# 514 U. S. CITATION
# Federal Gov-
#                      Cite JUDGE
# (2012)                   37 CITATION
# in question is ISSUE
# States.13
#    Acceptance JUDGE
# JUSTICE GINSBURG JUDGE
# n. 26 PROVISION
# n. 26 PROVISION
# Inc. v. Thornton CASENAME
# 514 U. S. 779 CITATION
# JUSTICE GINSBURG JUDGE
# NATIONAL FEDERATION JUDGE
# Mar. 28 PROVISION
# Medicaid Expan- JUDGE
# (2012)                39 CITATION
# §1396a(a) PROVISION
# Brief for Respondents CASENAME
# Federal
#  JUDGE
# §1396d(b) PROVISION
# States for Medicaid COURT
# Fiscal Year 2010 INSTRUMENT
# Office of Management CASENAME
# Table 12.3—Total Outlays for Grants to State and Local Gov- CASENAME
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# Report 47 PROVISION
# The Court of Appeals COURT
# 648 F. 3d 1235 CITATION
# Report 7 PROVISION
# Fiscal Year 2010 INSTRUMENT
# (2012)
#             41 CITATION
# Temporary Assistance for Needy Families (TANF) CASENAME
# Medical Treatment and Active Labor Act INSTRUMENT
# Medicaid
#  JUDGE
# NATIONAL FEDERATION JUDGE
# South Dakota v. Dole CASENAME
# Report 10 PROVISION
# Report 7 PROVISION
# (2012)             43 CITATION
# U. S. C. JUDGE
# Mar. 28 PROVISION
# NATIONAL FEDERATION JUDGE
# 42 U. S. C.
#  CASENAME
# §18041(c)(1 JUDGE
# Medicaid
#  JUDGE
# 26 U. S. C. §36B(c)
# (1)(B)(ii) CASENAME
# Con-
#  JUDGE
# Federal Gov- JUDGE
# (2012)
#             45 CITATION
# Douglas W. Elmen- JUDGE
# NATIONAL FEDERATION JUDGE
# Mar. 30 PROVISION
# R.
#  JUDGE
# & V. Chen CASENAME
# Extent and Causes of Variations INSTRUMENT
# Impacts 4 PROVISION
# n. 27 PROVISION
# Oral
#  JUDGE
# Mar. 28 PROVISION
# §§ JUDGE
# Financial Outlook for Medicaid CASENAME
# Medicaid
#  JUDGE
# Part IV PROVISION
# Part IV PROVISION
# C. J. JUDGE
# JJ.) JUDGE
# Medicaid Expansion CASENAME
# (2012)             47 CITATION
# Expansion INSTRUMENT
# Medi-
#  JUDGE
# Medicaid Expansion INSTRUMENT
# Fur-
#  JUDGE
# 100 U. S. 82 CITATION
# Chapter 7 PROVISION
# United States Code INSTRUMENT
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# Chapter 7 PROVISION
# Affordable Care Act INSTRUMENT
# (2012)
#             49 CITATION
# section
#  JUDGE
# Marbury v. Madison CASENAME
# 1 Cranch CASENAME
# Judiciary Act of 1789 INSTRUMENT
# Statutory Interpreta- JUDGE
# 295 U. S. 330 CITATION
# NATIONAL FEDERATION JUDGE
# The test LEGAL_TEST
# Alaska Airlines, Inc. v. Brock CASENAME
# S. 678 PROVISION
# Alaska Airlines CASENAME
# The question is ISSUE
# Free Enterprise Fund v. Public Company Account- CASENAME
# United States v. Booker CASENAME
# 543 U. S. 220 CITATION
# Con-
#                    Cite JUDGE
# (2012)             51 CITATION
# ___ JUDGE
# Ayotte v. Planned Parenthood CASENAME
# 546 U. S. 320 CITATION
# Telecommunications
#  JUDGE
# 518 U. S. 727 CITATION
# §10(a PROVISION
# NATIONAL FEDERATION JUDGE
# severability test LEGAL_TEST
# §1563 PROVISION
# T]his Act INSTRUMENT
# 26 U. S. C. §5000A(a) CASENAME
# Insur-
#  JUDGE
# §4980I JUDGE
# §§300gg–1 JUDGE
# §300gg–11 JUDGE
# §300gg–14(a) PROVISION
# §9010 PROVISION
# Reconciliation Act INSTRUMENT
# Medicaid
#  JUDGE
# §1396a(a)(10)(A)(i)(VIII) PROVISION
# 26 U. S. C. §36B CASENAME
# (2006
#                    Cite CITATION
# (2012)             53 CITATION
# §18071 PROVISION
# §1395ww(r) PROVISION
# Rev-
#  JUDGE
# Hospi-
#  JUDGE
# Medicaid Expan- JUDGE
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# §1501 PROVISION
# §1513 PROVISION
# Indi-
#  JUDGE
# §18091(2)(E) JUDGE
# §18091(2)(F) PROVISION
# §18091(2)(G) PROVISION
# §18091(2)(I) PROVISION
# §18091(2)(J) PROVISION
# Individual Man- JUDGE
# Williams v. Standard Oil Co. CASENAME
# 278 U. S. 235 CITATION
# (2012)
#             55 CITATION
# 1
#                The CITATION
# Affordable Care Act INSTRUMENT
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# Medicaid Expan- JUDGE
# Affordable Care Act INSTRUMENT
# Those
#  JUDGE
# 26 U. S. C. §4980I CASENAME
# §§300gg–1 JUDGE
# §300gg–11 JUDGE
# §300gg–14(a) PROVISION
# §9010 PROVISION
# §1401 PROVISION
# U. S. C. JUDGE
# (2012)
#             57 CITATION
# Individual Man- JUDGE
# Reimbursements to Hospitals and
#       Other Reductions CASENAME
# Medicare Expenditures
#   The Affordable Care Act CASENAME
# 42 U. S. C. §1395ww(b)(3)(B)(xi)–(xii) CASENAME
# §1395ww(q) PROVISION
# §1395ww(r) PROVISION
# §1396r JUDGE
# NATIONAL FEDERATION JUDGE
# §18091(2)(I) PROVISION
# §18091(2)(J) PROVISION
# Uncertain Times 5–6 CITATION
# Medicaid Expansion INSTRUMENT
# CBO Esti- JUDGE
# Table 2 PROVISION
# Mar. 20 PROVISION
# Support of Government’s Motion CASENAME
# (2012)
#             59 CITATION
# Legal Services Corporation v. Velazquez CASENAME
# 531 U. S. 533 CITATION
# ACA §§ JUDGE
# §18071 PROVISION
# Mar. 30 PROVISION
# With-
#  JUDGE
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# 42 U. S. C. §18031 CASENAME
# (2012)
#             61 CITATION
# Medicaid Expansion) COURT
# NATIONAL FEDERATION JUDGE
# 2
#                 The Act’s Minor Provisions
#     The CITATION
# 29 U. S. C. §207(r)(1)
#  CASENAME
# 21 U. S. C. §343(q)(5)(H) CASENAME
# §9015 PROVISION
# §1402 PROVISION
# U. S. C. JUDGE
# §4191 PROVISION
# §5000B. PROVISION
# §10323 PROVISION
# Medicare
#  JUDGE
# §2006 PROVISION
# N. Y. JUDGE
# Jan. 4 PROVISION
# (2012)
#             63 CITATION
# Offset Provisions JUDGE
# Medicaid Ex- JUDGE
# second test LEGAL_TEST
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# 100 U. S. CASENAME
# This Court COURT
# Indi-
#  JUDGE
# Medicaid Expansion CASENAME
# (2012)
#             65 CITATION
# Medicaid
#  JUDGE
# Structural
#  JUDGE
# Bill of Rights COURT
# (2012)            1
#
#                     THOMAS CITATION
# SUPREME COURT COURT
# PETITIONERS
#  JUDGE
# 11–393                 v.
#    CONCLUSION
# PETITIONERS
#
#  JUDGE
# 11–398                  JUDGE
# PETITIONERS
#  JUDGE
# ON WRITS OF CERTIORARI JUDGE
# UNITED STATES COURT COURT
# CHIEF JUSTICE cor- JUDGE
# United States v. Lopez CASENAME
# 514 U. S. 549 CITATION
# NATIONAL FEDERATION OF INDEPENDENT JUDGE
# ’ test LEGAL_TEST
# United States v. Morrison CASENAME
# 529 U. S. 598 CITATION
# Gonzales v. Raich CASENAME
# S. 1 PROVISION
# that test LEGAL_TEST

# %%
#display_casename_citations_filtered(doc)
def get_casename_citations_filtered(doc):
    '''Takes a spacy doc object and returns a dictionary of cases using the blackstone nlp model
    args:
        doc: the spacy doc object
    returns:
        
    '''
    cases = (i for i in doc.ents if i.label_ == 'CASENAME')
    actual_cases=[]
    results = {case:[item for item in case] for case in cases}
    return results

def get_actual_cases(case_list: dict) -> List:
    actual_cases = []
    for k, v in case_list.items():
        for i in v:
            if i.pos_ == 'ADP' and i.dep_ == 'prep':
                actual_cases.append(k)
    return actual_cases

def get_cases_from_doc(doc):
    return get_actual_cases(get_casename_citations_filtered(doc))

# %%
result = get_cases_from_doc(bx)

# %% [raw]
# actual_cases = []
#
# for k, v in result2.items():
#     for i in v:
#         if i.pos_ == 'ADP' and i.dep_ == 'prep':
#             actual_cases.append(k)
#     #print(k, [(i.text, i.pos_, i.dep_) for i in v if i.pos_ == 'ADP' and i.dep_ == 'prep'])
#     #if v
# print(actual_cases)

# %%
#how to get the cases
#get_actual_cases(get_casename_citations_filtered(doc))

# %%
cases_found = get_cases_from_doc(doc)
print('Cases found: ', [(i, i.label_) for i in cases_found])
# Out:
# Cases found:  [(United States v. Standard Oil Co., 'CASENAME'), (Dalehite v. United States,, 'CASENAME')]

# %%
#print(dir(spacy.tokens.Token))
#for i in cases_found:
#    for token in i:
#        print(token.text, token.pos_, token.dep_, [i for i in token.lefts], [i for i in token.rights])

# %%
@dataclass
class CaseWithNLP:
    case_name: str
    name_token: spacy.tokens.Token
    plaintiff: spacy.tokens.Token
    respondant: spacy.tokens.Token

# %%
def get_case_list(doc):
    result = get_cases_from_doc(doc)
    return result

# %%
res = make_case_with_nlp(doc)
print(res)
# Out:
# [United States v. Standard Oil Co., Dalehite v. United States,]

# %%
dir(spacy.tokens)
# Out:
# ['Doc',
#  'Span',
#  'Token',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_retokenize',
#  'doc',
#  'span',
#  'token',
#  'underscore',
#  'unicode_literals']
